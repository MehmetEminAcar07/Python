# %%
x<-54
y=34.5
100->z

# %%
x
y

z
# Out:
# [1] 54
# [1] 34.5
# [1] 100

# %%
print(x)
print(y)
print(z)
# Out:
# [1] 54
# [1] 34.5
# [1] 100

# %%
harf="a"
isim="Mehmet"
sehir="Ankara"

# %%
harf
isim
sehir
# Out:
# [1] "a"
# [1] "Mehmet"
# [1] "Ankara"
