# %%
veriler= data.frame(agirlik=c(140,155,159,179,192,200,212),
                    bacak_boyu=c(60,62,67,70,71,72,75))
veriler
# Out:
#   agirlik bacak_boyu
# 1 140     60
# 2 155     62
# 3 159     67
# 4 179     70
# 5 192     71
# 6 200     72
# 7 212     75

# %%
plot(veriler, main='ağırlıklar ile bacak boyu ilişkisi')
# Out:
# Plot with title "ağırlıklar ile bacak boyu ilişkisi"

# %%
veriseti= data.frame(çalışma_saati=c(1,2,4,5,5,6,6,7,8,10,11,11,12,12,14),
                     başarı=c(64,66,76,73,74,81,83,82,80,88,84,82,91,93,89))
veriseti
# Out:
#    çalışma_saati başarı
# 1   1            64
# 2   2            66
# 3   4            76
# 4   5            73
# 5   5            74
# 6   6            81
# 7   6            83
# 8   7            82
# 9   8            80
# 10 10            88
# 11 11            84
# 12 11            82
# 13 12            91
# 14 12            93
# 15 14            89

# %%
attach(veriseti)

# %%
scatter.smooth(çalışma_saati, başarı, main='Çalışma saatine göre başarı puanı')
# Out:
# Plot with title "Çalışma saatine göre başarı puanı"

# %%
boxplot(başarı)
# Out:
# plot without title

# %%
model=lm(başarı~çalışma_saati)

# %%
summary(model)
# Out:
# Call:
# lm(formula = başarı ~ çalışma_saati)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -5.140 -3.219 -1.193  2.816  5.772
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)     65.334      2.106  31.023 1.41e-13 ***
# çalışma_saati    1.982      0.248   7.995 2.25e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3.641 on 13 degrees of freedom
# Multiple R-squared:  0.831,	Adjusted R-squared:  0.818
# F-statistic: 63.91 on 1 and 13 DF,  p-value: 2.253e-06
