# %%
yas = c(25,16,38,45)
isim = c("Hasan", "Zehra", "Kamil", "Hatice")
adres = c("İstanbul", "Sakarya", "Ankara", "Mersin")

# %%
cerceve1 = data.frame(yas, isim, adres)
cerceve1
# Out:
#   yas isim   adres
# 1 25  Hasan  İstanbul
# 2 16  Zehra  Sakarya
# 3 38  Kamil  Ankara
# 4 45  Hatice Mersin

# %%
rownames(cerceve1) = c("1.sıra","2.sıra","3.sıra","4.sıra")
cerceve1
# Out:
#        yas isim   adres
# 1.sıra 25  Hasan  İstanbul
# 2.sıra 16  Zehra  Sakarya
# 3.sıra 38  Kamil  Ankara
# 4.sıra 45  Hatice Mersin

# %%
colnames(cerceve1) = c("yaş","ad","konum")
cerceve1
# Out:
#        yaş ad     konum
# 1.sıra 25  Hasan  İstanbul
# 2.sıra 16  Zehra  Sakarya
# 3.sıra 38  Kamil  Ankara
# 4.sıra 45  Hatice Mersin

# %%
cerceve1[2,3]
# Out:
# [1] Sakarya
# Levels: Ankara İstanbul Mersin Sakarya

# %%
üniversite = c("başkent", "Odtü", "Hacettepe", "Bilkent")

# %%
cerceve1
# Out:
#        yaş ad     konum
# 1.sıra 25  Hasan  İstanbul
# 2.sıra 16  Zehra  Sakarya
# 3.sıra 38  Kamil  Ankara
# 4.sıra 45  Hatice Mersin

# %%
cerceve2 = cbind(cerceve1, üniversite)

# %%
cerceve2
# Out:
#        yaş ad     konum    üniversite
# 1.sıra 25  Hasan  İstanbul başkent
# 2.sıra 16  Zehra  Sakarya  Odtü
# 3.sıra 38  Kamil  Ankara   Hacettepe
# 4.sıra 45  Hatice Mersin   Bilkent

# %%
cerceve3 = cerceve2[,-1]
cerceve3
# Out:
#        ad     konum    üniversite
# 1.sıra Hasan  İstanbul başkent
# 2.sıra Zehra  Sakarya  Odtü
# 3.sıra Kamil  Ankara   Hacettepe
# 4.sıra Hatice Mersin   Bilkent
