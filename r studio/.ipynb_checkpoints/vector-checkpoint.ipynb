# %%
v = c(7,8,10,3,5,1,18)
assign("v1",c(10,20,30,40,50))

# %%
print(v)
print(v1)
# Out:
# [1]  7  8 10  3  5  1 18
# [1] 10 20 30 40 50

# %%
v[1]
# Out:
# [1] 7

# %%
kv = c("Mehmet", "Emin", "Acar")

# %%
kv
# Out:
# [1] "Mehmet" "Emin"   "Acar"

# %%
x = c(1,3,5,7,9)
y = c(2,4,6,8,10)

# %%
toplam= x+y

# %%
toplam
# Out:
# [1]  3  7 11 15 19

# %%
x[5] = 11

# %%
x
# Out:
# [1]  1  3  5  7 11
