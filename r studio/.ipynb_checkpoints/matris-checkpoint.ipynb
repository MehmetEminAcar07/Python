# %%
matrisA = matrix(c(1,2,3,4,5,6), 3,2, byrow = TRUE)
matrisA
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6

# %%
matrisA = matrix(c(1,2,3,4,5,6), 3,2, byrow = FALSE)
matrisA
# Out:
#      [,1] [,2]
# [1,] 1    4
# [2,] 2    5
# [3,] 3    6

# %%
dim(matrisA)
# Out:
# [1] 3 2

# %%
karematris = matrix(c(1,2,3,4,5,6,7,8,9),3)
karematris
# Out:
#      [,1] [,2] [,3]
# [1,] 1    4    7
# [2,] 2    5    8
# [3,] 3    6    9

# %%
matrisB = cbind(c(1,2,3,4),c(5,6,7,8),c(9,10,11,12))
matrisB
# Out:
#      [,1] [,2] [,3]
# [1,] 1    5     9
# [2,] 2    6    10
# [3,] 3    7    11
# [4,] 4    8    12

# %%
matrisB = rbind(c(1,2,3,4),c(5,6,7,8),c(9,10,11,12))
matrisB
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 1     2    3    4
# [2,] 5     6    7    8
# [3,] 9    10   11   12

# %%
rbind(matrisB,c(13,14,15,16))
# Out:
#      [,1] [,2] [,3] [,4]
# [1,]  1    2    3    4
# [2,]  5    6    7    8
# [3,]  9   10   11   12
# [4,] 13   14   15   16

# %%
matrisB
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 1     2    3    4
# [2,] 5     6    7    8
# [3,] 9    10   11   12

# %%
cbind(matrisB,c(17,18,19,20))
# Out:
# Warning message in cbind(matrisB, c(17, 18, 19, 20)):
# "number of rows of result is not a multiple of vector length (arg 2)"
#      [,1] [,2] [,3] [,4] [,5]
# [1,] 1     2    3    4   17
# [2,] 5     6    7    8   18
# [3,] 9    10   11   12   19

# %%
matrisB[,-5]
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 1     2    3    4
# [2,] 5     6    7    8
# [3,] 9    10   11   12

# %%
faktör1 = factor(c("kadın", "erkek", "kadın", "kadın", "erkek"))
faktör1
# Out:
# [1] kadın erkek kadın kadın erkek
# Levels: erkek kadın

# %%
table(faktör1)
# Out:
# faktör1
# erkek kadın
#     2     3
