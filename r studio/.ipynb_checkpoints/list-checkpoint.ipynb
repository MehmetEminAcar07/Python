# %%
liste1 = list(54)
print(liste1)
# Out:
# [[1]]
# [1] 54

# %%
liste2 = list(54, "S", TRUE)
print(liste2)
# Out:
# [[1]]
# [1] 54
#
# [[2]]
# [1] "S"
#
# [[3]]
# [1] TRUE

# %%
yas = c(25,35,45,55)
kan = c("A","B","0","AB")
sonuc = c(FALSE, TRUE, FALSE, TRUE)

# %%
liste3 = list(yas, kan, sonuc)

# %%
liste3
# Out:
# [[1]]
# [1] 25 35 45 55
#
# [[2]]
# [1] "A"  "B"  "0"  "AB"
#
# [[3]]
# [1] FALSE  TRUE FALSE  TRUE
